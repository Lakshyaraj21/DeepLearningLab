# %% [markdown]
# <a href="https://colab.research.google.com/github/Lakshyaraj21/DeepLearningLab/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Hello World')
# Out:
# Hello World

# %%
ls
# Out:
# '23c96a66-5096-4bdf-81e1-d18285800419 (1).JPG'
# 'answers of QUIZ 2.docx'
# 'Assignment 2.pdf'
# 'ASSIGNMENT2 SOLUTION by Chirag.docx'
# 'Capstone Project  G3.gdoc'
# 'CAPSTONE PROJECT_GROUP 10 (dd) (1).docx'
#  ch1.gslides
# 'Class Activity 6.docx'
# 'Class Activity 7.gdoc'
#  Classroom/
# 'Colab Notebooks'/
#  E-JOURNAL.docx
# 'Exercise 6 (5).xlsx'
# 'Format Capstone Project Working with Data.pdf'
#  Games.csv
# 'Getting started.pdf'
#  IMG_0235.png
#  IMG_2651.HEIC
# 'IMG_2652 (1).HEIC'
#  IMG_2652.HEIC
# 'Intro to AIML'/
# 'LABEXP5 .docx'
# 'Lab experiment 4 '/
# 'Lakshyaraj_500108693_Web tech.gdoc'
# 'Lakshyaraj Sisodia - Assignment II.gdoc'
# 'Lc Assignment -- Body Language and Overall Communication'/
# 'LC Assignment Communication Styles'/
# 'Lc Assignment Cross Culture Communication'/
# 'Lc assignment Global Guest Talk'/
# 'Lc assignment listening for improved understanding '/
# 'LC Assignment Setting Communication Goals & Avoiding Breakdowns'/
# ...

# %%
# %cd drive/MyDrive/
# Out:
# /content/drive/MyDrive

# %%
import pandas as pd
pd.read_csv('web-show 250.csv')
# Out:
#      Unnamed: 0                           names relese_date run_time  \
# 0             0                  1 Breaking Bad   2008–2013   62 eps
# 1             1               2 Planet Earth II        2016    6 eps
# 2             2                  3 Planet Earth        2006   11 eps
# 3             3              4 Band of Brothers        2001   10 eps
# 4             4                     5 Chernobyl        2019    5 eps
# ..          ...                             ...         ...      ...
# 245         245              21 The Vietnam War        2017   10 eps
# 246         246                     22 Sherlock   2010–2017   15 eps
# 247         247              23 Attack on Titan   2013–2023   98 eps
# 248         248  24 Batman: The Animated Series   1992–1995   85 eps
# 249         249                   25 The Office   2005–2013  188 eps
#
#     rating_tag  rating
# 0        TV-MA     9.5
# 1         TV-G     9.5
# 2        TV-PG     9.4
# 3        TV-MA     9.4
# ...
